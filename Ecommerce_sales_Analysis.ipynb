# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset = pd.read_excel(r"C:\Users\HP\OneDrive\Desktop\Data analysis project\Ecommerce_sales_analysis\Superstore_USA.xlsx")
dataset.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
dataset.shape
# Out:
# (9426, 24)

# %%
dataset.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
dataset["Product Base Margin"] = dataset["Product Base Margin"].fillna(dataset["Product Base Margin"].mean())

# %%
dataset.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
dataset.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          9426.000000   9426.000000                           9426
# mean              0.512189  52446.327286  2012-03-05 18:33:59.465308672
# min               0.350000   1001.000000            2010-01-01 00:00:00
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
dataset.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %% [markdown]
# # Order Priority

# %%
dataset["Order Priority"].value_counts()    # show me a total order priority with particular order
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %% [markdown]
# #in which two critical so replace into 1

# %%
dataset["Order Priority"].unique()  # describe unique value
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
dataset["Order Priority"] = dataset["Order Priority"].replace('Critical ', 'Critical')    # replaced critcial beacuase this dublicate

# %%
dataset["Order Priority"].value_counts()   # in which sol critical thing
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: count, dtype: int64

# %%
plt.figure(figsize = (5,4.5))
ax = sns.countplot(x = "Order Priority", data = dataset)
ax.bar_label(ax.containers[0])
plt.title("Count of Order Priority")
plt.savefig("Count of Order Priotity.jpg")

# %% [markdown]
# # Ship Mode

# %%
dataset["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
plt.figure(figsize = (5,5))
ship = dataset["Ship Mode"].value_counts()
plt.pie(ship, labels= ship.index, autopct = "%1.1f%%")
plt.title("Distribution of ship mode")
plt.legend(loc = 1)
plt.savefig("Ship mode.jpg")

# %% [markdown]
# #The count plot visualizes the number of orders for each Ship Mode, grouped by Product Category

# %%
# Shiping mode analysis
plt.figure(figsize = (5,4))
a = sns.countplot(x = "Ship Mode", data = dataset, hue = "Product Category")  # hue is used for all product category in which how much order that why hue is used
a.bar_label(a.containers[0])
plt.title("Distribution of Orders by Ship Mode and Product Category")
plt.show()

# %% [markdown]
# # Product Category

# %%
dataset["Product Category"].value_counts()
# Out:
# Product Category
# Office Supplies    5181
# Technology         2312
# Furniture          1933
# Name: count, dtype: int64

# %%
x = sns.countplot(x = "Product Category", data = dataset)
x.bar_label(x.containers[0])
plt.title("Distribution of Product Category")
plt.show()

# %% [markdown]
# # Customer Segment

# %%
dataset["Customer Segment"].value_counts()
# Out:
# Customer Segment
# Corporate         3375
# Home Office       2316
# Consumer          1894
# Small Business    1841
# Name: count, dtype: int64

# %%
cust = sns.countplot(x = "Customer Segment", data = dataset)
cust.bar_label(cust.containers[0])
plt.title("Distribution of Customer Segment")
# Out:
# Text(0.5, 1.0, 'Distribution of Customer Segment')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %% [markdown]
# # product sub category

# %%
dataset["Product Sub-Category"].value_counts()
# Out:
# Product Sub-Category
# Paper                             1379
# Binders and Binder Accessories    1028
# Telephones and Communication       992
# Office Furnishings                 883
# Computer Peripherals               846
# Pens & Art Supplies                721
# Storage & Organization             610
# Appliances                         492
# Chairs & Chairmats                 440
# Tables                             404
# Office Machines                    376
# Labels                             329
# Envelopes                          272
# Bookcases                          206
# Rubber Bands                       195
# Scissors, Rulers and Trimmers      155
# Copiers and Fax                     98
# Name: count, dtype: int64

# %%
x = sns.countplot(x = "Product Category", data = dataset, hue = "Product Sub-Category")
x.bar_label(x.containers[0])
plt.title("Distribution of Product Category")
# Out:
# Text(0.5, 1.0, 'Distribution of Product Category')

# %% [markdown]
# #Analyzing the Distribution of Office Supplies by Sub-Category

# %%
sns.countplot(x = "Product Category", data = dataset[dataset["Product Category"]=="Office Supplies"], hue = "Product Sub-Category")
plt.legend(title="Product Sub-Category", prop={'size': 5})
plt.title("Distribution of Office Supplies by Product Sub-Category")
# Out:
# Text(0.5, 1.0, 'Distribution of Office Supplies by Product Sub-Category')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
dataset["Order Date"].dt.year    # this is for year diff showing
# Out:
# 0       2012
# 1       2010
# 2       2011
# 3       2011
# 4       2011
#         ...
# 9421    2013
# 9422    2013
# 9423    2013
# 9424    2010
# 9425    2013
# Name: Order Date, Length: 9426, dtype: int32

# %%
dataset["Order year"] =dataset["Order Date"].dt.year  # this command add order year column

# %%
dataset.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
# in which year how much order placed
dataset["Order year"].value_counts()
# Out:
# Order year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %%
Oy = sns.countplot(x = "Order year", data = dataset)
Oy.bar_label(Oy.containers[0])
plt.title("Distribution of Orders by Year")
# Out:
# Text(0.5, 1.0, 'Distribution of Orders by Year')

# %% [markdown]
# #find in which category in which how much profit

# %%
ax = sns.barplot(x = "Product Category", y="Profit", data = dataset, estimator = "sum")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '451990'), Text(0, 0, '683098'), Text(0, 0, '177354')]

# %% [markdown]
# # State or Province

# %%
dataset["State or Province"].value_counts()[:5]  # 5 is used for top 5 state
# Out:
# State or Province
# California    1021
# Texas          646
# Illinois       584
# New York       574
# Florida        522
# Name: count, dtype: int64

# %% [markdown]
# #showing that top 5 state by order count

# %%
x = dataset["State or Province"].value_counts()[:5]
plt.pie(x, labels = x.index, autopct = "%1.1f%%")
plt.title("Dsitribution of top 5 state by order count")
# Out:
# Text(0.5, 1.0, 'Dsitribution of top 5 state by order count')

# %%
 # calculate Total Product Base Margin by Product Category
ax = sns.barplot(x = "Product Category", y="Product Base Margin", data = dataset, estimator = "sum")
ax.bar_label(ax.containers[0]) 
plt.title("Total Product Base Margin by Product Category")
# Out:
# Text(0.5, 1.0, 'Total Product Base Margin by Product Category')

# %% [markdown]
# # Solution:
#
# # Missing Data Handling:
#
# The dataset had missing values in the "Product Base Margin" column, which was successfully imputed with the mean value for a consistent dataset.
#
# # Order Priority Distribution:
#
# The "Order Priority" column shows the following distribution:
# High: 1970 orders
# Low: 1926 orders
# Not Specified: 1881 orders
# Medium: 1844 orders
# Critical: 1805 orders
# A slight discrepancy in the "Critical" order priority was resolved by standardizing duplicate entries (e.g., "Critical " to "Critical").
#
# # Ship Mode Analysis:
#
# The most common shipping mode is Regular Air, accounting for 7036 orders (75% of the total orders).
# Delivery Truck follows with 1283 orders (14% of the total orders).
# Express Air is the least used with 1107 orders (11% of total orders).
# A pie chart visualizes the distribution of shipping modes.
#
# # Orders by Product Category:
#
# Office Supplies is the most ordered product category, with 5181 orders.
# The distribution of orders by ship mode for different product categories shows varying preferences for shipping methods based on the type of product ordered.
#
# # Product Sub-Category Insights:
#
# Specific product sub-categories such as Binders and Paper dominate in the office supplies category.
# Technology-related products are also significant, with varying shipping preferences based on urgency.
# # Profit and Sales Analysis:
#
# The Profit and Sales columns show a wide range of values with the highest profit recorded at 16332.41 and the highest sales at 100119.16.
# Negative profit values indicate possible loss-making orders that could be further investigated for improvements.
#
# # Quantity Ordered:
#
# The average quantity ordered is around 13.8 units, with some orders reaching up to 170 units.
# # Shipping Cost vs. Sales:
#
# A noticeable trend shows that higher shipping costs correlate with higher sales, suggesting that more expensive shipping options are chosen for higher-value orders.
# Geographic Insights:
#
# The dataset covers multiple regions and states, with Central and West regions having a high number of orders. Specific cities and postal codes show higher concentrations of orders.
# # Time-Based Insights:
#
# The order dates range from 2010 to 2014, with peak sales occurring in the years 2011 to 2013, suggesting certain seasonal trends.
# # Actionable Insights:
#
# The company could optimize shipping strategies, considering that most orders use "Regular Air" as the shipping method.
# Further analysis could focus on Critical orders to identify any bottlenecks or delays in processing.
# Investigate orders with negative profits to identify root causes and improve profitability.
